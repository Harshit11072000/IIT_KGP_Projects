# %%
# !pip install beautifulsoup4
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\harshit singh\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\harshit singh\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.wbhealth.gov.in/pages/search_hospitals"
page = requests.get(URL)

soup = BeautifulSoup(page.content,'html.parser')
all_divs = soup.find('div',{'id':'nameSearch'})

# %%
all_divs

# %%
results = soup.find(id='s_district')
print(results.prettify())
# Out:
# <select id="s_district" name="s_district" onchange="this.form.submit()">
#  <option value="">
#   Select District
#  </option>
#  <option value="Alipurduar">
#   Alipurduar
#  </option>
#  <option value="Bankura">
#   Bankura
#  </option>
#  <option value="Bardhaman">
#   Bardhaman
#  </option>
#  <option value="Birbhum">
#   Birbhum
#  </option>
#  <option value="Dakshin Dinajpur">
#   Dakshin Dinajpur
#  </option>
#  <option value="Darjeeling">
#   Darjeeling
#  </option>
#  <option value="Howrah">
#   Howrah
#  </option>
#  <option value="Hooghly">
#   Hooghly
#  </option>
#  <option value="Jalpaiguri">
#   Jalpaiguri
#  </option>
#  <option value="Cooch Behar">
#   Cooch Behar
#  </option>
#  <option value="Kolkata">
#   Kolkata
#  </option>
#  <option value="Malda">
#   Malda
#  </option>
#  <option value="Murshidabad">
#   Murshidabad
#  </option>
#  <option value="Nadia">
#   Nadia
#  </option>
#  <option value="North 24 Pgs">
#   North 24 Pgs
#  </option>
# ...

# %%
from selenium import webdriver
from time import sleep
import bs4

# %%
type(d1)
# Out:
# list

# %%
import pandas as pd
webscrap = ['Alipurduar','Bankura','Bardhaman','Birbhum','Dakshin Dinajpur','Darjeeling','Howrah','Hooghly','Jalpaiguri','Cooch Behar','Kolkata','Malda','Murshidabad','Nadia','North 24 Pgs','Paschim Medinipur','Purba Medinipur','Purulia','South 24 Pgs','Uttar Dinajpur']
driver = webdriver.Chrome(executable_path=r"C:\Users\Harshit Singh\Downloads\chromedriver_win32\chromedriver.exe")
sleep(2)
driver.get("https://www.wbhealth.gov.in/pages/search_hospitals/Alipurdar")
sleep(2)

d2 = []
search = driver.find_element_by_id("s_district")
search.send_keys(webscrap[19])
sleep(2)
    
res =driver.find_element_by_xpath("/html/body/div[3]/div/div/table/tbody/tr/td[2]/div/table/tbody/tr/td[1]/div/div/div/div[2]/div").get_attribute("outerHTML")
    
d1 = pd.read_html(res)

driver.close()

# %%
d5 = pd.DataFrame(d1[0])

# %%
df = d5[d5[0].notna()]

# %%
df
# Out:
#       0                      1               2                3             4  \
# 0   No.  Hospital/ Institution        District         Location   Post Office
# 1     1            Kunour BPHC  Uttar Dinajpur       Kaliyaganj        Kunour
# 3     2            Rampur BPHC  Uttar Dinajpur          Raiganj  Maharaja hat
# 5     3             Raiganj DH  Uttar Dinajpur          Raiganj       Raiganj
# 7     4      Urban Health Care  Uttar Dinajpur          Raiganj       Raiganj
# 9     5  Kasba Police Hospital  Uttar Dinajpur          Raiganj       Raiganj
# 11    6            Daspara PHC  Uttar Dinajpur           Chopra       Daspara
# 13    7           Lakhipur PHC  Uttar Dinajpur           Chopra    Lakhsmipur
# 15    8            Sonapur PHC  Uttar Dinajpur           Chopra       Sonapur
# 17    9            Goagaon PHC  Uttar Dinajpur   Goalpokher - I       Goagaon
# 19   10              Kanki PHC  Uttar Dinajpur  Goalpokher - II         Kanki
# ...

# %%
writer2 = pd.ExcelWriter('3.xlsx')
df.to_excel(writer2)
writer2.save()
