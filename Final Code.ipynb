# %%
import pandas as pd

# %%
d1 = pd.read_excel("DistanceMatrixWB_BLocks.xlsx")

# %%
d1 = pd.DataFrame(d1)

# %%
d1['Block Name']
# Out:
# 0            Alipurduar - II
# 1                    Amdanga
# 2                  Amta - II
# 3                    Arambag
# 4                      Arsha
#                ...
# 260    Thakurpukur Mahestola
# 261           Tufanganj - II
# 262           Udaynarayanpur
# 263            Uluberia - II
# 264                Vishnupur
# Name: Block Name, Length: 265, dtype: object

# %%
import numpy as np

# %%
d1['Block'] =d1['Block Name'].astype(str) + ', West Bengal'

# %%
d1['Block'].values
# Out:
# array(['Alipurduar - II, West Bengal', 'Amdanga, West Bengal',
#        'Amta - II, West Bengal', 'Arambag, West Bengal',
#        'Arsha, West Bengal', 'Ausgram - II, West Bengal',
#        'Baduria, West Bengal', 'Bagda, West Bengal',
#        'Bagmundi, West Bengal', 'Bagnan - II, West Bengal',
#        'Balagarh, West Bengal', 'Balarampur, West Bengal',
#        'Bally Jagachha, West Bengal', 'Balurghat, West Bengal',
#        'Bamangola, West Bengal', 'Bankura - II, West Bengal',
#        'Bansihari, West Bengal', 'Barabani, West Bengal',
#        'Barabazar, West Bengal', 'Barasat - II, West Bengal',
#        'Barjora, West Bengal', 'Barrackpur - II, West Bengal',
#        'Baruipur, West Bengal', 'Basanti, West Bengal',
#        'Basirhat - II, West Bengal', 'Beldanga - II, West Bengal',
#        'Berhampore, West Bengal', 'Bhagawangola - II, West Bengal',
#        'Bhagawanpur - II, West Bengal', 'Bhangar - II, West Bengal',
# ...

# %%
distance = [[]]

# %%
from selenium import webdriver
from time import sleep

# %%
distance = []
state_capi = [
       'Bally Jagachha, West Bengal', 'Balurghat, West Bengal',
       'Bamangola, West Bengal', 'Bankura - II, West Bengal',
       'Bansihari, West Bengal', 'Barabani, West Bengal',
       'Barabazar, West Bengal', 'Barasat - II, West Bengal',
       'Barjora, West Bengal', 'Barrackpur - II, West Bengal',
       'Baruipur, West Bengal', 'Basanti, West Bengal',
       'Basirhat - II, West Bengal', 'Beldanga , West Bengal',
       'Berhampore, West Bengal', 'Bhagawangola - II, West Bengal',
       'Bhagawanpur - II, West Bengal', 'Bhangar - II, West Bengal',
       'Bharatpur - II, West Bengal', 'Bhatar, West Bengal',
       'Binpur - II, West Bengal', 'Bishnupur - II, West Bengal',
       'Bolpur Sriniketan, West Bengal', 'Bongaon, West Bengal',
       'Budge Budge - II, West Bengal', 'Bundwan, West Bengal',
       'Burdwan - II, West Bengal', 'Burwan, West Bengal',
       'Canning - II, West Bengal', 'Chakdah, West Bengal',
       'Chanchal - II, West Bengal', 'Chandipur, West Bengal',
       'Chanditala - II, West Bengal', 'Chandrakona - II, West Bengal',
       'Chapra, West Bengal', 'Chhatna, West Bengal',
       'Chinsurah - Magra, West Bengal', 'Chopra, West Bengal',
       'Contai - III, West Bengal', 'Cooch Behar - II, West Bengal',
       'Dantan - II, West Bengal', 'Darjeeling Pulbazar, West Bengal',
       'Daspur - II, West Bengal', 'Debra, West Bengal',
       'Deganga, West Bengal', 'Deshopran, West Bengal',
       'Dhaniakhali, West Bengal', 'Dhupguri, West Bengal',
       'Diamond Harbour - II, West Bengal', 'Dinhata - II, West Bengal',
       'Domjur, West Bengal', 'Domkal, West Bengal',
       'Dubrajpur, West Bengal', 'Egra - II, West Bengal',
       'English Bazar, West Bengal', 'Falakata, West Bengal',
       'Falta, West Bengal', 'Farakka, West Bengal',
       'Faridpur Durgapur, West Bengal', 'Gaighata, West Bengal',
       'Galsi - II, West Bengal', 'Gangajalghati, West Bengal',
       'Gangarampur, West Bengal', 'Garbeta - III, West Bengal',
       'Gazole, West Bengal', 'Ghatal, West Bengal',
       'Goalpokhar - II, West Bengal', 'Goghat - II, West Bengal',
       'Gopiballavpur - II, West Bengal', 'Gorubathan, West Bengal',
       'Gosaba, West Bengal', 'Habibpur, West Bengal',
       'Habra - II, West Bengal', 'Haldia, West Bengal',
       'Haldibari, West Bengal', 'Hanskhali, West Bengal',
       'Hariharpara, West Bengal', 'Haringhata, West Bengal',
       'Haripal, West Bengal', 'Harirampur, West Bengal',
       'Harischandrapur - II, West Bengal', 'Haroa, West Bengal',
       'Hasnabad, West Bengal', 'Hemtabad, West Bengal',
       'Hilli, West Bengal', 'Hingalganj, West Bengal',
       'Hirbandh, West Bengal', 'Hura, West Bengal',
       'Illambazar, West Bengal', 'Indpur, West Bengal',
       'Indus, West Bengal', 'Islampur, West Bengal',
       'Itahar, West Bengal', 'Jagatballavpur, West Bengal',
       'Jaipur, West Bengal', 'Jalangi, West Bengal',
       'Jalpaiguri, West Bengal', 'Jamalpur, West Bengal',
       'Jamboni, West Bengal', 'Jamuria, West Bengal',
       'Jangipara, West Bengal', 'Jaynagar - II, West Bengal',
       'Jaypur, West Bengal', 'Jhalda - II, West Bengal',
       'Jhargram, West Bengal', 'Jorebunglow Sukiapokhri, West Bengal',
       'Kakdwip, West Bengal', 'Kalchini, West Bengal',
       'Kaliachak - III, West Bengal', 'Kaliaganj, West Bengal',
       'Kaliganj, West Bengal', 'Kalimpong - II, West Bengal',
       'Kalna - II, West Bengal', 'Kandi, West Bengal',
       'Kanksa, West Bengal', 'Karandighi, West Bengal',
       'Karimpur - II, West Bengal', 'Kashipur, West Bengal',
       'Katwa - II, West Bengal', 'Keshiary, West Bengal',
       'Keshpur, West Bengal', 'Ketugram - II, West Bengal',
       'Khanakul - II, West Bengal', 'Khandaghosh, West Bengal',
       'Kharagpur - II, West Bengal', 'Khargram, West Bengal',
       'Kharibari, West Bengal', 'Khatra, West Bengal',
       'Khejuri - II, West Bengal', 'Khoyrasol, West Bengal',
       'Kolaghat, West Bengal', 'Kotulpur, West Bengal',
       'Krishnaganj, West Bengal', 'Krishnagar - II, West Bengal',
       'Kulpi, West Bengal', 'Kultali, West Bengal',
       'Kumarganj, West Bengal', 'Kumargram, West Bengal',
       'Kurseong, West Bengal', 'Kushmundi, West Bengal',
       'Labpur, West Bengal', 'Lalgola, West Bengal',
       'Madarihat, West Bengal', 'Magrahat - II, West Bengal',
       'Mahisadal, West Bengal', 'Mal, West Bengal',
       'Maldah (Old), West Bengal', 'Manbazar - II, West Bengal',
       'Mandirbazar, West Bengal', 'Mangolkote, West Bengal',
       'Manikchak, West Bengal', 'Manteswar, West Bengal',
       'Mathabhanga - II, West Bengal', 'Mathurapur - II, West Bengal',
       'Matiali, West Bengal', 'Matigara, West Bengal',
       'Maynaguri, West Bengal', 'Mayureswar - II, West Bengal',
       'Mejhia, West Bengal', 'Mekliganj, West Bengal',
       'Memari - II, West Bengal', 'Midnapore, West Bengal',
       'Minakhan, West Bengal', 'Mirik, West Bengal',
       'Mohammad Bazar, West Bengal', 'Mohanpur, West Bengal',
       'Moyna, West Bengal', 'Murarai - II, West Bengal',
       'Murshidabad Jiaganj, West Bengal', 'Nabadwip, West Bengal',
       'Nabagram, West Bengal', 'Nagrakata, West Bengal',
       'Nakashipara, West Bengal', 'Nalhati - II, West Bengal',
       'Namkhana, West Bengal', 'Nanda Kumar, West Bengal',
       'Nandigram - II, West Bengal', 'Nanoor, West Bengal',
       'Narayangarh, West Bengal', 'Nawda, West Bengal',
       'Naxalbari, West Bengal', 'Nayagram, West Bengal',
       'Neturia, West Bengal', 'Onda, West Bengal', 'Andal, West Bengal',
       'Panchla, West Bengal', 'Pandabeswar, West Bengal',
       'Pandua, West Bengal', 'Panskura, West Bengal',
       'Para, West Bengal', 'Patharpratima, West Bengal',
       'Patrasayer, West Bengal', 'Phansidewa, West Bengal',
       'Pingla, West Bengal', 'Polba - Dadpur, West Bengal',
       'Potashpur - II, West Bengal', 'Puncha, West Bengal',
       'Purbasthali - II, West Bengal', 'Pursura, West Bengal',
       'Purulia - II, West Bengal', 'Raghunathganj - II, West Bengal',
       'Raghunathpur - II, West Bengal', 'Raiganj, West Bengal',
       'Raina - II, West Bengal', 'Raipur, West Bengal',
       'Rajarhat, West Bengal', 'Rajganj, West Bengal',
       'Rajnagar, West Bengal', 'Ramnagar - II, West Bengal',
       'Rampurhat - II, West Bengal', 'Ranaghat - II, West Bengal',
       'Rangli Rangliot, West Bengal', 'Ranibundh, West Bengal',
       'Raniganj, West Bengal', 'Raninagar - II, West Bengal',
       'Ratua - II, West Bengal', 'Sabang, West Bengal',
       'Sagar, West Bengal', 'Sagardighi, West Bengal',
       'Sahid Matangini, West Bengal', 'Sainthia, West Bengal',
       'Salanpur, West Bengal', 'Salbani, West Bengal',
       'Saltora, West Bengal', 'Samserganj, West Bengal',
       'Sandeshkhali - II, West Bengal', 'Sankrail, West Bengal',
       'Sankrail, West Bengal', 'Santipur, West Bengal',
       'Santuri, West Bengal', 'Sarenga, West Bengal',
       'Serampore ,West Bengal','Uttarpara, West Bengal', 'Shyampur - II, West Bengal',
       'Simlapal, West Bengal', 'Singur, West Bengal',
       'Sitai, West Bengal', 'Sitalkuchi, West Bengal',
       'Sonamukhi, West Bengal', 'Sonarpur, West Bengal',
       'Suri - II, West Bengal', 'Sutahata, West Bengal',
       'Suti - II, West Bengal', 'Swarupnagar, West Bengal',
       'Taldangra, West Bengal', 'Tamluk, West Bengal',
       'Tapan, West Bengal', 'Tarakeswar, West Bengal',
       'Tehatta - II, West Bengal', 'Thakurpukur Mahestola, West Bengal',
       'Tufanganj - II, West Bengal', 'Udaynarayanpur, West Bengal',
       'Uluberia - II, West Bengal', 'Vishnupur, West Bengal']
driver = webdriver.Chrome(executable_path=r"C:\Users\Harshit Singh\Downloads\chromedriver_win32\chromedriver.exe")
sleep(2)
driver.get("https://www.google.co.in/maps/@23.7187323,86.9545401,14z")
sleep(2)
Place = driver.find_element_by_class_name("tactile-searchbox-input")
Place.send_keys(state_capi[0])
Submit = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button")
Submit.click()
        
sleep(8)
directions = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[8]/div/div[1]/div/div/div[4]/div[1]/div/button/img")
directions.click()

for j in range(1,len(state_capi)):
    
        sleep(3)
        find = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/div/div/input")
        find.clear()
        find.send_keys(state_capi[j])
        sleep(3)
        search = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/button[1]")
        search.click()
           
        search1 = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[2]/div/div/div[1]/div[2]/button/img")
        search1.click()
           
        sleep(10)
        totalkilometers = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[8]/div/div[1]/div/div/div[8]/div[1]/div/div[1]/div[1]/div[2]/div")
        distance.append(totalkilometers.text)
        #sleep(5)
        #Bus = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[8]/div/div[1]/div/div/div[5]/div/div/div[1]/div[1]/div[1]/span[1]")
        #print("Bus travel time",Bus.text)
        
        sleep(2)
        find.clear()
           
        #find = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/div/div/input")
        #find.send_keys("Kharagpur")
        #Submit = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/button[1]")         #Submit.click()
        #search1 = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[2]/div/div/div[1]/div[2]/button/img")
        #search1.click()
           
        continue
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-3-1a3fc46c98b3> in <module>
#     161
#     162         sleep(2)
# --> 163         find.clear()
#     164
#     165         #find = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/div/div/input")
#
# c:\users\harshit singh\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webelement.py in clear(self)
#      93     def clear(self):
#      94         """Clears the text if it's a text entry element."""
# ---> 95         self._execute(Command.CLEAR_ELEMENT)
#      96
#      97     def get_property(self, name):
#
# c:\users\harshit singh\appdata\local\programs\python\python37\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
# ...

# %%
import pandas as pd
dis = pd.DataFrame(distance)

# %%
dis
# Out:
#           0
# 0    420 km
# 1    356 km
# 2    198 km
# 3    373 km
# 4    203 km
# 5    289 km
# 6   23.2 km
# 7    165 km
# 8   24.1 km
# 9   52.1 km
# 10  91.8 km
# 11  57.0 km
# 12   187 km
# 13   215 km
# 14   247 km
# 15  69.9 km
# 16  43.4 km
# 17   174 km
# 18   112 km
# 19   169 km
# 20   125 km
# 21   147 km
# 22  75.2 km
# 23  45.9 km
# 24   272 km
# 25  88.4 km

# %%
writer2 = pd.ExcelWriter('2.xlsx')
dis.to_excel(writer2)
writer2.save()
