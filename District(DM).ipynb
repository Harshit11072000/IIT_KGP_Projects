# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.read_excel("DistMat.xlsx",skiprows=[0],header=None)
d2 = pd.DataFrame(d1)

# %%
d2[0][:] = d2[0][:].astype(str) + ',West Bengal'

# %%
from selenium import webdriver
from time import sleep

# %%
distance_overall = [[]]
driver = webdriver.Chrome(executable_path=r"C:\Users\Harshit Singh\Downloads\chromedriver_win32\chromedriver.exe")
sleep(2)
driver.get("https://www.google.co.in/maps/@23.7187323,86.9545401,14z")
sleep(2)
for i in range(1,21):
    distance = []
    ##state_capi = ['Alipurduar','Bankura','Bardhaman','Birbhum','Dakshin Dinajpur','Darjeeling','Howrah','Hooghly','Jalpaiguri','Cooch Behar','Kolkata','Malda','Murshidabad','Nadia','North 24 Pgs','Paschim Medinipur','Purba Medinipur','Purulia','South 24 Pgs','Uttar Dinajpur']
    Place = driver.find_element_by_class_name("tactile-searchbox-input")
    Place.clear()
    Place.send_keys(d2[0][i])
    Submit = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button")
    Submit.click()
        
    sleep(8)
    directions = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[8]/div/div[1]/div/div/div[4]/div[1]/div/button/img")
    directions.click()
    for j in range(i+1,21):
        sleep(2)
        find = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/div/div/input")
        find.clear()
        find.send_keys(d2[0][j])
        sleep(2)
        search = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[3]/div[1]/div[1]/div[2]/button[1]")
        search.click()
           
        search1 = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[2]/div/div/div[1]/div[2]/button/img")
        search1.click()
           
        sleep(5)
        totalkilometers = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[8]/div/div[1]/div/div/div[7]/div[1]/div/div[1]/div[1]/div[2]/div")
        distance.append(totalkilometers.text)
        
        sleep(2)
        find.clear()
           
        continue
    distance_overall.append(distance)    
    Place1 = driver.find_element_by_xpath("/html/body/jsl/div[3]/div[9]/div[3]/div[1]/div[2]/div/div[2]/div/button/div[1]")
    Place1.click()
driver.close()

# %%
distance
# Out:
# []

# %%
distance_overall
# Out:
# [[],
#  ['656 km',
#   '587 km',
#   '543 km',
#   '361 km',
#   '704 km',
#   '213 km',
#   '659 km',
#   '128 km',
#   '22.9 km',
#   '685 km',
#   '362 km',
#   '505 km',
#   '590 km',
#   '676 km',
#   '772 km',
#   '792 km',
#   '665 km',
#   '750 km',
#   '287 km'],
#  ['96.2 km',
#   '113 km',
#   '360 km',
#   '168 km',
#   '583 km',
#   '169 km',
#   '560 km',
#   '652 km',
#   '198 km',
#   '287 km',
#   '204 km',
#   '185 km',
#   '194 km',
#   '116 km',
#   '234 km',
#   '86.8 km',
#   '289 km',
#   '439 km'],
#  ['82.4 km',
#   '301 km',
#   '98.0 km',
#   '521 km',
#   '74.3 km',
#   '498 km',
#   '591 km',
#   '103 km',
#   '231 km',
#   '149 km',
#   '89.1 km',
#   '99.2 km',
#   '128 km',
#   '206 km',
#   '188 km',
#   '179 km',
#   '359 km'],
#  ['256 km',
#   '180 km',
#   '477 km',
#   '156 km',
#   '454 km',
#   '546 km',
#   '185 km',
#   '188 km',
#   '101 km',
#   '132 km',
#   '180 km',
#   '217 km',
#   '287 km',
#   '166 km',
#   '261 km',
#   '314 km'],
#  ['412 km',
#   '284 km',
#   '373 km',
#   '261 km',
#   '353 km',
#   '399 km',
#   '74.8 km',
#   '217 km',
#   '304 km',
#   '390 km',
#   '429 km',
#   '506 km',
#   '391 km',
#   '465 km',
#   '122 km'],
#  ['615 km',
#   '47.2 km',
#   '592 km',
#   '684 km',
#   '16.3 km',
#   '325 km',
#   '222 km',
#   '138 km',
#   '21.1 km',
#   '120 km',
#   '120 km',
#   '282 km',
#   '75.1 km',
#   '453 km'],
#  ['590 km',
#   '110 km',
#   '211 km',
#   '617 km',
#   '292 km',
#   '436 km',
#   '522 km',
#   '608 km',
#   '704 km',
#   '724 km',
#   '597 km',
#   '682 km',
#   '170 km'],
#  ['572 km',
#   '664 km',
#   '54.4 km',
#   '307 km',
#   '181 km',
#   '96.4 km',
#   '50.5 km',
#   '157 km',
#   '157 km',
#   '261 km',
#   '131 km',
#   '432 km'],
#  ['96.8 km',
#   '592 km',
#   '268 km',
#   '412 km',
#   '497 km',
#   '583 km',
#   '679 km',
#   '699 km',
#   '572 km',
#   '657 km',
#   '145 km'],
#  ['685 km',
#   '360 km',
#   '505 km',
#   '590 km',
#   '676 km',
#   '773 km',
#   '792 km',
#   '665 km',
#   '750 km',
#   '282 km'],
#  ['332 km',
#   '228 km',
#   '123 km',
#   '8.1 km',
#   '128 km',
#   '128 km',
#   '288 km',
#   '62.8 km',
#   '458 km'],
#  ['141 km',
#   '229 km',
#   '315 km',
#   '354 km',
#   '431 km',
#   '315 km',
#   '389 km',
#   '131 km'],
#  ['109 km', '195 km', '265 km', '324 km', '264 km', '269 km', '273 km'],
#  ['108 km', '243 km', '243 km', '272 km', '182 km', '361 km'],
#  ['136 km', '136 km', '285 km', '75.0 km', '455 km'],
#  ['126 km', '193 km', '153 km', '566 km'],
#  ['309 km', '95.5 km', '562 km'],
#  ['366 km', '448 km'],
#  ['520 km'],
#  []]

# %%
d5 = pd.DataFrame(distance_overall)
d5
# Out:
#          0        1        2        3        4        5        6        7   \
# 0      None     None     None     None     None     None     None     None
# 1    656 km   587 km   543 km   361 km   704 km   213 km   659 km   128 km
# 2   96.2 km   113 km   360 km   168 km   583 km   169 km   560 km   652 km
# 3   82.4 km   301 km  98.0 km   521 km  74.3 km   498 km   591 km   103 km
# 4    256 km   180 km   477 km   156 km   454 km   546 km   185 km   188 km
